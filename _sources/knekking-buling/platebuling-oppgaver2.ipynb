# %% [markdown]
# # Platebuling oppgaver 2
#
# <p style="text-align:center;">
#     ✍️ Lars Erik Nygård  <a href="mailto:lars.e.nygard@ntnu.no">📧</a> 10.02.2024 📅
# </p>

# %% [markdown]
# Vi skal her se på to platefelt som er like store, men som har ulik stiverretning.
#
# I alle oppgavene skal en anta følgende:
#
# - trykkspenning $ \sigma = 120 \frac{N}{mm^2} $
# - Poisson's ratio $ \nu = 0.3 $
# - E modul $ 210000\frac{N}{mm^2} $
# - flytspenning $ \sigma_{flyt} = 235 \frac{N}{mm^2}  $
# - tetthet stål $ \rho = 7850 \frac{kg}{m^3} $

# %% [markdown]
# ### Regneøving 1 ###
#
# Hva er minste tykkelse gitt i halve milimeter platen kan være før den buler? Topologi er angitt på tegningen.
# Beregn vekten av hele platen.
# <br>
#
# ![image.png](attachment:image.png)

# %%
# Din kode skriver du her. 
### Prosedyre
#- Identifiser spenningstilfelle fra bulekoeffisientarket. 
#- Beregn spenningsvariasjonen psi  
#- Beregn tilhørende bulekoeffisient C. 
#- Beregn Eulerspenning gitt aspektforhold t/s og materialparameterene E og possions ratio 
#- Korriger evt for Johnson Ostenfeld

# %% [markdown]
# ### Regneøving 2 ###
# Hva er minste tykkelse gitt i halve milimeter platen kan være før den buler? Topologi er angitt på tegningen.
# Hva blir vekten av hele platen?
# <br>
# ![image-2.png](attachment:image-2.png)

# %%
# Din kode skriver du her.

# %% [markdown]
# ### Regneøving 3 ###
#
# Introduser en eller flere rader med bulestivere på skottet i oppgave 2.
# Hva blir minste vekten av hele platen + bulestiverne (anta rektangulære tverrsnitt 100x8)
#
# Sammenlign resultatet med vektene du fikk i oppgave 1 og 2.

# %%
# Din kode skriver du her.
