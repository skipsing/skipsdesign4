# %% [markdown]
# # Platebuling oppgaver
#
# <p style="text-align:center;">
#     ✍️ Lars Erik Nygård  <a href="mailto:lars.e.nygard@ntnu.no">📧</a> 26.02.2024 📅
# </p>

# %% [markdown]
# ### Regneøving 1 ###
#
# Vi skal kontrollere platefeltet under for buling. Platefeltet er belastet med en varierende trykkspenning langs kortsiden.
# <br>
#
# ![image.png](attachment:image.png)
#
# $$ E_{modul} = 210 000 \frac{N}{mm^2} $$
#
# <br>
#
# $$ \sigma_{flyt} = 355 \frac{N}{mm^2} $$

# %%
# Din kode skriver du her. 
### Prosedyre
#- Identifiser spenningstilfelle fra bulekoeffisientarket. 
#- Beregn spenningsvariasjonen psi  
#- Beregn tilhørende bulekoeffisient C. 
#- Beregn Eulerspenning gitt aspektforhold t/s og materialparameterene E og possions ratio 
#- Korriger evt for Johnson Ostenfeld

# %% [markdown]
# Løsningsforslag:
# <br>
# - Tilfelle a) (eller c) Begge vil lede fram.
# <br>
# - $\psi$ = 0
# <br>
# - $C = 7.63$
# <br>
# - $\sigma_{Euler}= 144 \frac{N}{mm^2} $
# <br>
# - Ingen korreksjon -> $\sigma_{kr} = \sigma_{Euler}$
# <br>
# - $\sigma_{kr} < \sigma$ -> Platefeltet vil bule.

# %% [markdown]
# ### Regneøving 2 ###
#
# Vi skal kontrollere platefeltet under for buling. Platefeltet er belastet med en varierende trykkspenning langs kortsiden.
# <br>
# ![image.png](attachment:image.png)
#
# $$ E_{modul} = 210 000 \frac{N}{mm^2} $$
#
# <br>
#
# $$ \sigma_{flyt} = 355 \frac{N}{mm^2} $$

# %%
# Din kode skriver du her.

# %% [markdown]
# Løsningsforslag:
#
# - Tilfelle c)
#
# - $ \psi = -0.1333 $
#
# - $ C = 1.017 $
#
# - $ \sigma_{Euler}= 6.94 \frac{N}{mm^2} $
#
# - Ingen korreksjon -> $ \sigma_{kr} = \sigma_{Euler} $
#
# - $ \sigma_{kr} < \sigma $ -> Platefeltet vil bule.

# %% [markdown]
# ### Regneøving 3 ###
#
# Vi skal kontrollere platefeltet under for buling. Platefeltet er belastet med en varierende trykkspenning langs kortsiden.
# <br>
# ![image.png](attachment:image.png)
#
# $$ E_{modul} = 210 000 \frac{N}{mm^2} $$
#
# <br>
#
# $$ \sigma_{flyt} = 355 \frac{N}{mm^2} $$

# %%
# Din kode skriver du her.

# %% [markdown]
# Løsningsforslag
#
# ...

# %% [markdown]
# ### Regneøving 4 ###
#
# Vi skal kontrollere platefeltet under for buling. Platefeltet er belastet med en varierende trykkspenning langs kortsiden.
# <br>
# ![image-2.png](attachment:image-2.png)
#
# $$ E_{modul} = 210 000 \frac{N}{mm^2} $$
#
# <br>
#
# $$ \sigma_{flyt} = 355 \frac{N}{mm^2} $$

# %%
# Din kode skriver du her.

# %% [markdown]
# ## Øving eget prosjekt
#
# Du skal nå estimere nødvendig platetykkelse du trenger i hoveddekk og bunn for å sikre at buling ikke inntreffer i ditt prosjekt.
#
# Bruk stillevannsmomentet du har fra lastkombinasjonene i Maxsurf. Dette skal kombineres med bølgemomentet fra regelverket (Se i DNV-RU-SHIP Pt.3 Ch.4 Sec.3.1):
#
# $$ M_w = 0.19 \times C_w \times L^2 \times B \times C_B \text{ [kNm]} $$
#
# Og der $ C_W $ er en bølgekoeffisient gitt som:
#
# $$ C_W = 10.75 - (\frac{300 - L }{100})^{1.5} $$
#
# Tips: Gjør skrogbjelken din om til en ekvivalent I-bjelke som er litt enklere å regne på. Bruk *xls kalkulatoren* du lagde i Styrkeberegninger. "Gjett" på startverdier for tykkelse i dekk, bunn, side og langskipskott.

# %% [markdown]
# ## Øving eget prosjekt Del II

# %% [markdown]
# Hva skjer om du snur stiverretningen? Dvs at platefeltet blir rotert 90 grader og langsiden på platen står på tverrs? Anta alle andre variabler likt. Hva blir platetykkelsen nå?
